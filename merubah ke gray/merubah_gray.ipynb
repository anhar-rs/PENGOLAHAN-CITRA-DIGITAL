# %% [markdown]
# import library yang dibutuhkan

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

# %% [markdown]
# membaca gambar

# %%
gambar=cv.imread("D:/semester 4/PCD/materi/PENGOLAHAN-CITRA-DIGITAL/aang.jpg")
plt.title("latihan grayscale")
plt.imshow(gambar)

# %% [markdown]
# merubah ke gray scale

# %%
gambar_abu=cv.cvtColor(gambar,cv.COLOR_BGR2GRAY)
plt.imshow(gambar_abu,cmap="gray")
