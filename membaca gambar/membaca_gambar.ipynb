# %% [markdown]
# import library yang dibutuhkan

# %%
import numpy as np
import cv2 as cv

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# membaca poto dengan path yang ada

# %%
gambar=cv.imread("D:/semester 4/PCD/materi/PENGOLAHAN-CITRA-DIGITAL/aang.jpg")

# %% [markdown]
# menampilkan poto

# %%
plt.title("avatar")
plt.imshow(gambar)
plt.show()
